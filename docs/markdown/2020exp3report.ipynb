# %% [markdown]
#  # 実世界情報実験３ロボットテーマレポート

# %% [markdown]
# 氏名

# %% [markdown]
# 学生番号

# %% [markdown]
# 日付

# %% [markdown]
# ## １． ロボットの操作とROSの基礎

# %% [markdown]
# ### 課題１

# %% [markdown]
# ![hardware_setup.png](attachment:hardware_setup.png)
